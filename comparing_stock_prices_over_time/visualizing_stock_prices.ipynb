# %%
import pandas as pd 
from utils import get_dataframe

# %%
df_AAPL = get_dataframe(ticker="AAPL")
df_INTC = get_dataframe(ticker="INTC")

# %%
ready_df = df_INTC.merge(df_AAPL, left_index=True, right_index=True)

# %%
ready_df.plot(xlabel="Year", ylabel="Price, $", title="Comparison of Intel and Apple stock prices", rot=0)
# Out:
# <Axes: title={'center': 'Comparison of Intel and Apple stock prices'}, xlabel='Year', ylabel='Price, $'>
